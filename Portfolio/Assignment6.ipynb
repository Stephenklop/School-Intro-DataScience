# %% [markdown]
# # Assignment 6

# %%
# Import external libraries
import pandas as pd

# %%
# Load the dataset
covidSet = pd.read_csv('Assignment4.csv', sep=',')

# %% [markdown]
# ## Perform a univariate analysis on at least 2 columns with categorical data and on at least 2 columns with numerical data

# %% [markdown]
# ### Univariate analysis: Categorical data on the continent table

# %%
covidSet['continent']
# Out:
# 0           Asia
# 1           Asia
# 2           Asia
# 3           Asia
# 4           Asia
#            ...
# 157703    Africa
# 157704    Africa
# 157705    Africa
# 157706    Africa
# 157707    Africa
# Name: continent, Length: 157708, dtype: object

# %%
covidSet['continent'].unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
covidSet['continent'].value_counts()
# Out:
# Africa           37382
# Europe           35207
# Asia             34397
# North America    23635
# South America     9101
# Oceania           8511
# Name: continent, dtype: int64

# %%
covidSet['continent'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Univariate analysis: Categorical data on the location table

# %%
covidSet['location']
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 157703       Zimbabwe
# 157704       Zimbabwe
# 157705       Zimbabwe
# 157706       Zimbabwe
# 157707       Zimbabwe
# Name: location, Length: 157708, dtype: object

# %%
covidSet['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
covidSet['location'].value_counts()
# Out:
# Mexico       758
# Argentina    758
# Peru         758
# Thailand     755
# Taiwan       743
#             ...
# Tuvalu       179
# Palau        159
# Tokelau      114
# Pitcairn      85
# Niue          43
# Name: location, Length: 238, dtype: int64

# %%
covidSet['location'].value_counts().plot(kind='bar', figsize=(35, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Univariate analysis: Numerical data on the total_cases table

# %%
cases = covidSet['total_cases']

# %%
cases.min()
# Out:
# 1.0

# %%
cases.max()
# Out:
# 366249339.0

# %%
cases.mean()
# Out:
# 2254539.7996887392

# %%
cases.median();

# %%
cases.std();

# %%
cases.plot(kind='hist', bins = 100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
cases.plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Univariate analysis: Numerical data on the new_cases_smoothed_per_million

# %%
casesPerMillion = covidSet['new_cases_smoothed_per_million']

# %%
casesPerMillion.min()
# Out:
# -272.971

# %%
casesPerMillion.max()
# Out:
# 15886.607

# %%
casesPerMillion.mean()
# Out:
# 129.6444644043394

# %%
casesPerMillion.median()
# Out:
# 17.035

# %%
casesPerMillion.std()
# Out:
# 391.53724435888597

# %%
casesPerMillion.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
casesPerMillion.plot(kind = 'box')
# Out:
# <AxesSubplot:>
